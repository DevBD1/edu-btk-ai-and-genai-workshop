# %%
import pandas as pd

df = pd.DataFrame({
    "ad": [
        "Ali", "Ayse", "Mehmet", "Zeynep",
        "Can", "Elif", "Mert", "Deniz", "Ece", "Kerem",
        "Sena", "Hakan", "Buse", "Ozan", "Selin",
        "Emre", "Ceren", "Tolga", "Derya", "Baran",
        "Irem", "Kaan", "Yasemin", "Onur", "Pelin",
        "Fatih", "Gizem", "Umut", "Naz", "Burak"
    ],
    "yas": [
        25, None, 40, None,
        31, 22, None, 28, None, 35,
        27, None, 24, 33, None,
        29, 26, None, 41, 30,
        None, 38, 23, None, 32,
        36, None, 21, None, 34
    ],
    "puan": [
        85, 90, None, 75,
        None, 88, 92, None, 80, None,
        95, None, 78, None, 83,
        None, 91, 76, None, 89,
        74, None, None, 87, None,
        93, 79, None, 82, None
    ],
    "sehir": [
        None, None, None, None,
        None, None, None, None, None, None,
        None, None, None, None, None,
        None, None, None, None, None,
        None, None, None, None, None,
        None, None, None, None, None
    ]
})

print("Eksik Sayilari:\n", df.isna().sum())
print("\nEksiklik Orani (%):\n", (df.isna().sum() / len(df)) * 100)
# Out:
# Eksik Sayilari:
#  ad        0
# yas      11
# puan     13
# sehir    30
# dtype: int64
#
# Eksiklik Orani (%):
#  ad         0.000000
# yas       36.666667
# puan      43.333333
# sehir    100.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib .pyplot as plt

# Eksik verileri gorsel olarak analiz etmek
fig, ax = plt.subplots(figsize =(6, 3))
sns.heatmap(df.isna(), cbar=False , cmap="Reds", ax=ax)
ax.set_title("Eksik Veri Haritasi (Kirmizi = NaN)")
plt.show()
